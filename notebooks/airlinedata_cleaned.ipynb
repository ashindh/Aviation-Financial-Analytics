# %%
#libraries
import pandas as pd

# %%
#importing file
df=pd.read_csv("/content/Aviation_KPIs_Dataset.csv")

# %%
df.head()
# Out:
#   Flight Number Scheduled Departure Time Actual Departure Time  \
# 0         FL885      2024-05-20 11:51:21   2024-07-10 02:38:54
# 1         FL930      2024-01-23 06:56:23   2024-07-07 02:53:44
# 2         FL478      2024-05-30 09:18:39   2024-12-05 01:00:54
# 3         FL637      2024-08-15 05:21:47   2024-09-21 13:23:42
# 4         FL318      2024-07-25 15:29:58   2024-03-21 15:05:54
#
#    Delay (Minutes)  Aircraft Utilization (Hours/Day)  \
# 0               50                             12.36
# 1               27                             14.53
# 2              108                             10.73
# 3               64                             15.10
# 4               30                             13.46
#
#    Turnaround Time (Minutes)  Load Factor (%)  Fleet Availability (%)  \
# 0                        115            79.18                   96.24
# 1                         83            98.59                   80.49
# ...

# %%
#data auditing
#missing values
df.isnull().sum()
# Out:
# Flight Number                       0
# Scheduled Departure Time            0
# Actual Departure Time               0
# Delay (Minutes)                     0
# Aircraft Utilization (Hours/Day)    0
# Turnaround Time (Minutes)           0
# Load Factor (%)                     0
# Fleet Availability (%)              0
# Maintenance Downtime (Hours)        0
# Fuel Efficiency (ASK)               0
# Revenue (USD)                       0
# Operating Cost (USD)                0
# Net Profit Margin (%)               0
# Ancillary Revenue (USD)             0
# Debt-to-Equity Ratio                0
# Revenue per ASK                     0
# Cost per ASK                        0
# Profit (USD)                        0
# dtype: int64

# %%
#duplecates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Create the cost to revenue
df['Cost_to_Revenue_Ratio'] = df['Operating Cost (USD)'] / df['Revenue (USD)']

# %%
#Find profitable or loss
df['Is_Profitable'] = (df['Profit (USD)'] > 0).astype(int)

# %%
print(df[['Revenue (USD)', 'Operating Cost (USD)', 'Cost_to_Revenue_Ratio', 'Profit (USD)', 'Is_Profitable']].head(5))
# Out:
#    Revenue (USD)  Operating Cost (USD)  Cost_to_Revenue_Ratio  Profit (USD)  \
# 0       10953.75              27847.59               2.542288     -16893.84
# 1       31597.25               1564.41               0.049511      30032.84
# 2       13700.27              30494.88               2.225860     -16794.61
# 3       39913.01              13444.09               0.336835      26468.92
# 4       11531.48              34668.98               3.006464     -23137.50
#
#    Is_Profitable
# 0              0
# 1              1
# 2              0
# 3              1
# 4              0
